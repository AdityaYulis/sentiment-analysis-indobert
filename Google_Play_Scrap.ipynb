# %%
from google_play_scraper import reviews
import pandas as pd

# %%
APP_ID = "com.kai.kaiticketing"
TOTAL_REVIEWS = 5000

all_reviews = []

print("Scraping reviews...")
# Out:
# Scraping reviews...

# %%
result, continuation_token = reviews(
    APP_ID,
    lang="id",
    country="id",
    count=200
)

all_reviews.extend(result)

while len(all_reviews) < TOTAL_REVIEWS:

    result, continuation_token = reviews(
        APP_ID,
        continuation_token=continuation_token
    )

    if not result:
        break

    all_reviews.extend(result)

print("Total reviews:", len(all_reviews))
# Out:
# Total reviews: 5000

# %%
df = pd.DataFrame(all_reviews)

# %%
df
# Out:
#                                   reviewId            userName  \
# 0     52d425f8-891e-4c65-b8b2-20b3b892e817        Ian Kampleng
# 1     c53f2561-1600-4fcc-ba2f-77e440750562          Ibnu Surya
# 2     d427e908-d177-4624-b15c-ca4f6f144571    Muhamad Mulyanto
# 3     418d4ade-3a45-4082-9e23-9968872e682b     gilang bhaskara
# 4     27bafe76-0686-4cb9-9823-c6a2c7f69f73          Hanny_hans
# ...                                    ...                 ...
# 4995  b7930127-6a3f-4be8-af74-dd2da3ca82e6  M. Rifqi Sistianto
# 4996  69023664-b8bd-4f4c-8c0c-fc01f9667554        Rosy Alfiani
# 4997  31b80279-4c7c-4853-b62b-f37eeddf316e        Dariman Dive
# 4998  3ce51bba-f37a-4f81-9c67-0b6a0b720758        Rafli Darren
# 4999  5acdb608-602e-41d8-ab4b-c88a13c6d2dc  Rifki Nur fadhilah
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a/ACg8oc...
# 2     https://play-lh.googleusercontent.com/a-/ALV-U...
# 3     https://play-lh.googleusercontent.com/a/ACg8oc...
# 4     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                 ...
# 4995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4997  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                 content  score  thumbsUpCount  \
# 0     koq tiba2 skrng HP sy tidak suport sih sm acce...      5              0
# 1     aplikasi ini sangat bagus, sangat membantu dal...      5              0
# 2     KAI TOLONG PERBAIKI SISTEM CIKARANG - BEKASI D...      1              0
# 3     aplikasi bapuk, pas mau berangkat eh ada gangg...      2              0
# 4     Ko bisa tetiba ilang akun gw pas buka hrs biki...      1              0
# ...                                                 ...    ...            ...
# 4995                                                oke      1              0
# 4996  aplikasinya cukup enak buat pesen tiket, sayan...      1              0
# 4997                                    sangat membantu      5              0
# 4998  aplikasi yang sangat berguna, membantu masyara...      5              0
# 4999                    tiket ku yang udah kebeli ilang      1              0
#
#      reviewCreatedVersion                  at replyContent repliedAt  \
# 0                  6.17.0 2026-04-28 06:38:40         None       NaT
# 1                  6.17.1 2026-04-28 05:58:23         None       NaT
# 2                  6.18.0 2026-04-28 05:00:50         None       NaT
# 3                    None 2026-04-28 03:31:17         None       NaT
# 4                  6.18.0 2026-04-27 23:59:20         None       NaT
# ...                   ...                 ...          ...       ...
# 4995               6.14.8 2025-12-15 05:20:52         None       NaT
# 4996                6.6.1 2025-12-15 04:52:56         None       NaT
# 4997               6.14.8 2025-12-15 04:26:42         None       NaT
# 4998               6.15.1 2025-12-15 04:03:06         None       NaT
# 4999               6.14.8 2025-12-15 04:00:30         None       NaT
#
#      appVersion
# 0        6.17.0
# 1        6.17.1
# 2        6.18.0
# 3          None
# 4        6.18.0
# ...         ...
# 4995     6.14.8
# 4996      6.6.1
# 4997     6.14.8
# 4998     6.15.1
# 4999     6.14.8
#
# [5000 rows x 11 columns]

# %%
df = pd.DataFrame(all_reviews)

df = df[[
    "content",
    "score"
]]

df.columns = [
    "review",
    "rating"
]

df.to_csv(
    "raw_reviews.csv",
    index=False
)

print("Saved to data/raw/raw_reviews.csv")
# Out:
# Saved to data/raw/raw_reviews.csv
